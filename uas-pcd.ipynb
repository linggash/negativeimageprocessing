# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('../input/negativefilm/CIOS.jpg')
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)



img_negative = 255 - img

plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_negative,cmap="gray")
plt.show()

# %%
img = cv2.imread('../input/negativefilm/MASJID.jpg')
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)



img_negative = 255 - img

plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_negative,cmap="gray")
plt.show()

# %%
img2 = cv2.imread('../input/negativefilm/020211004_2004377052.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)



img_negative2 = 255 - img2

plt.figure(figsize=(20, 20))
plt.subplot(1,2,1)
plt.imshow(img2, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(img_negative2,cmap="gray")
plt.show()
